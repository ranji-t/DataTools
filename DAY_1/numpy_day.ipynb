# %%
import numpy as np 
from time import perf_counter

# %%
np.iinfo(np.uint16)
# Out:
# iinfo(min=0, max=65535, dtype=uint16)

# %%
np.finfo(np.float64)
# Out:
# finfo(resolution=1e-15, min=-1.7976931348623157e+308, max=1.7976931348623157e+308, dtype=float64)

# %%
# %%timeit -n 500 -r 500

sum = 0

for i in range(100_000):
    sum += i
# Out:
# 3.16 ms ± 112 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 500 -r 500

np.arange(100_000).sum()
# Out:
# 42.6 µs ± 3.6 µs per loop (mean ± std. dev. of 500 runs, 500 loops each)

# %%
np.arange(100_000)
# Out:
# array([    0,     1,     2, ..., 99997, 99998, 99999])

# %%
np.array(
    [
        [
            [1,2,3],
            [10,20,30],
        ],
        [
            [10_00000, 1_0000, 100_0000],
            [10_00000, 1_0000, 100_0000],
        ]
    ]
)
# Out:
# array([[[      1,       2,       3],
#         [     10,      20,      30]],
#
#        [[1000000,   10000, 1000000],
#         [1000000,   10000, 1000000]]])

# %%
import matplotlib.pyplot as plt

# %%
from glob import glob

# %%
img = plt.imread('C:\\Users\\RanjithRajmohan\\Pictures\\VastaLorde.png')

# %%
plt.imshow(img[:, (img.shape[1] // 2):, :])

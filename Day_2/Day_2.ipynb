# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = plt.imread('C:\\Users\\RanjithRajmohan\\Pictures\\VastaLorde.png')

# %%
img.mean(axis=-1).shape
# Out:
# (1920, 2560)

# %%
img_2 = img.copy()

# %%
img_2[:,:,[0,0,0]]
# Out:
# array([[[0.10588235, 0.10588235, 0.10588235],
#         [0.10588235, 0.10588235, 0.10588235],
#         [0.09411765, 0.09411765, 0.09411765],
#         ...,
#         [0.23921569, 0.23921569, 0.23921569],
#         [0.27450982, 0.27450982, 0.27450982],
#         [0.2784314 , 0.2784314 , 0.2784314 ]],
#
#        [[0.10588235, 0.10588235, 0.10588235],
#         [0.10588235, 0.10588235, 0.10588235],
#         [0.09019608, 0.09019608, 0.09019608],
#         ...,
#         [0.23529412, 0.23529412, 0.23529412],
#         [0.27450982, 0.27450982, 0.27450982],
#         [0.27450982, 0.27450982, 0.27450982]],
#
#        [[0.10588235, 0.10588235, 0.10588235],
#         [0.10196079, 0.10196079, 0.10196079],
#         [0.08627451, 0.08627451, 0.08627451],
#         ...,
#         [0.23529412, 0.23529412, 0.23529412],
#         [0.27450982, 0.27450982, 0.27450982],
#         [0.27450982, 0.27450982, 0.27450982]],
#
#        ...,
#
#        [[0.14509805, 0.14509805, 0.14509805],
# ...

# %%
plt.imshow(img.mean(axis=-1), cmap='gray')

# %%
plt.imshow(img_2[:,:,[0,0,0]])

# %%
plt.imshow(img_2[:,:,[1,1,1]])

# %%
plt.imshow(img_2[:,:,[2,2,2]])

# %%
img_3 = img_2[:,:,[0,1,2,0]]

# %%
img_3[:,:,[3]] = 0.5

# %%
plt.imshow(img_3)

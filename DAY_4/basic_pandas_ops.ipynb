# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import fetch_california_housing 


cal_hsn = fetch_california_housing()

# %%
cl = pd.DataFrame(cal_hsn.data, columns=cal_hsn.feature_names)

# %%
DATA_PATH: str = r"D:\CodeBase\Personal\RustyPanda\data\titanic_train.csv"

# %%
df = pd.read_csv(
    DATA_PATH,
    dtype={
        'PassengerId': np.uint16,
        'Survived': bool,
        'Pclass': 'category',
        'Sex': 'category',
        'Age': np.float16,
        'SibSp': np.uint8,
        'Parch': np.uint8,
        'Fare': np.float16,
        'Embarked': 'category'
    },
    # chunksize=100
)

# %%
df
# Out:
#      PassengerId  Survived Pclass  \
# 0              1     False      3
# 1              2      True      1
# 2              3      True      3
# 3              4      True      1
# 4              5     False      3
# ..           ...       ...    ...
# 886          887     False      2
# 887          888      True      1
# 888          889     False      3
# 889          890      True      1
# 890          891     False      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby('Sex')[['Fare', 'Age']].agg([min, max, np.mean, np.median, np.std, len])
# Out:
#         Fare                                                Age        \
#          min    max       mean median        std  len       min   max
# Sex
# female  6.75  512.5  44.481552   23.0  58.004199  314  0.750000  63.0
# male    0.00  512.5  25.524439   10.5  43.144485  577  0.419922  80.0
#
#
#              mean median        std  len
# Sex
# female  27.915709   27.0  14.110146  314
# male    30.726645   29.0  14.678201  577

# %%
df.groupby('Sex')[['Survived']].agg(['count', sum, lambda x: x.sum()/x.count()])
# Out:
#        Survived
#           count  sum <lambda_0>
# Sex
# female      314  233   0.742038
# male        577  109   0.188908

# %%
df.groupby('Sex').agg(
    total_count = ('Survived', 'count'),
    survived_count = ('Survived', 'sum'),
    percent_survived = ('Survived', lambda x: x.sum()*100/x.count()),
)
# Out:
#         total_count  survived_count  percent_survived
# Sex
# female          314             233         74.203822
# male            577             109         18.890815
